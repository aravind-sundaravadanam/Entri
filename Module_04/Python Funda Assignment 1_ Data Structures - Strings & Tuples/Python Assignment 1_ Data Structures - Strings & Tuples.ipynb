# %% [markdown]
# #**Python Assignment 1: Data Structures - Strings & Tuples**

# %% [markdown]
# ##1.String Concatenation:

# %%
Your_Name = input("Enter your name: ")
greeting_message = "Hello "+ Your_Name
print(greeting_message)
# Out:
# Enter your name: Aravind
# Hello Aravind

# %%
Your_Name = input("Enter your name: ")
greeting_message = "Hello "+ Your_Name + "," + " Welcome to Python Programming"
print(greeting_message)
# Out:
# Enter your name: Aravind
# Hello Aravind, Welcome to Python Programming

# %% [markdown]
# ##2.String Slicing and Indexing:

# %%
# 2.String Slicing and Indexing:
# a.Print the first character of the string.
print(greeting_message[0])
# b.Print the last character of the string.
print(greeting_message[43])
# c.Print the first 5 characters of the string.
print(greeting_message[0:6])
# d.Print the last 11 characters of the string.
print(greeting_message[-11:]) #Using negative index
# e.Print the string in reverse.
print(greeting_message[::-1])
# f.Use slicing and print the word “Python” from the existing string.
print(greeting_message[-18:-12]) #Using negative index
# Out:
# H
# g
# Hello
# Programming
# gnimmargorP nohtyP ot emocleW ,dnivarA olleH
# Python

# %%
print('its working on mobile')
# Out:
# its working on mobile

# %% [markdown]
# ##3. String Methods:

# %%
strM = 'Python beginner tutorial'
print(strM)
# Out:
# Python beginner tutorial

# %%
# a. Convert the sentence to uppercase.
strM.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %%
# b.Convert the sentence to lowercase.
strM.lower()
# Out:
# 'python beginner tutorial'

# %%
# c.Use Capitalize and return the sentence to the original input form.
strM.capitalize()
# Out:
# 'Python beginner tutorial'

# %%
# d.Count the total number of occurrences of character ‘t’ in the string.
strM.count('t')
# Out:
# 3

# %%
# e.Replace all occurrences of “Python” with “Machine Learning” in the input string strM = “Python beginner tutorial”
strM = input('Input String: ')
strM = strM.replace('Python', 'Machine Learning')  # replaced string is assign back to strM.
print('Replaced String: ' + strM)
# Out:
# Input String: Python beginner tutorial
# Replaced String: Machine Learning beginner tutorial

# %% [markdown]
# #Tuples

# %%
# a. Concatenate the two tuples and store it in “t_combine”

TUPLE1 = (10, 20, 30)
TUPLE2 = (40, 50, 60)
t_combine = TUPLE1 + TUPLE2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
# b.Repeat the elements of “t_combine” 3 times
t_combine = t_combine*3
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
# c.Access the 3rd element from “t_combine”
print(t_combine[2])
# Out:
# 30

# %%
#d.Access the first three elements from “t_combine”
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %%
# e.Access the last three elements from “t_combine”
print(t_combine[-3:])
# Out:
# (40, 50, 60)

# %% [markdown]
# Learning oct 4
