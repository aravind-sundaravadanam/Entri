# %% [markdown]
# #List (Creation, Modifi cation and Access):

# %% [markdown]
# ##1. List Creation:

# %%
  # a. Create a list named age_list with five integer elements. For eg., [24, 25, 26, 27, 28]

age_list = [30,45,56,35,48]
print(age_list)
# Out:
# [30, 45, 56, 35, 48]

# %%
# b.Create a list named name_list with five string elements.
name_list = ['Rajesh','Rajive','Gowtham','Reena','Swathi']
print(name_list)
# Out:
# ['Rajesh', 'Rajive', 'Gowtham', 'Reena', 'Swathi']

# %% [markdown]
# ##2. List Operations / Modifications:

# %%
# a. Append the string "Yazhini" to name_list.
name_list.append('Yazhini')
print(name_list)
# Out:
# ['Rajesh', 'Rajive', 'Gowtham', 'Reena', 'Swathi', 'Yazhini']

# %%
# b. Insert the element 30 at index 2 in age_list.

age_list.insert(2,30)
print(age_list)
# Out:
# [30, 45, 30, 56, 35, 48]

# %%
# c. Remove the string "Yazhini" from name_list.
name_list.remove('Yazhini')
print(name_list)
# Out:
# ['Rajesh', 'Rajive', 'Gowtham', 'Reena', 'Swathi']

# %%
# d. Pop the last element from age_list.
age_list.pop()
print(age_list)
# Out:
# [30, 45, 30, 56, 35]

# %%
# e. Extend the age_list with additional ages [29, 30, 26]

age_list.extend([29,30,26])
print(age_list)
# Out:
# [30, 45, 30, 56, 35, 29, 30, 26]

# %%
# f. Sort age_list in descending order.
age_list.sort(reverse=True)
print(age_list)
# Out:
# [56, 45, 35, 30, 30, 30, 29, 26]

# %%
# g. Find Max age, Min age and sum of all ages from age_list.
max_age = max(age_list)
min_age = min(age_list)
total_age = sum(age_list)

print("Max Age:", max_age)
print("Min Age:", min_age)
print("Sum of all Ages:", total_age)
# Out:
# Max Age: 56
# Min Age: 26
# Sum of all Ages: 281

# %% [markdown]
# ##3. Accessing List Elements:

# %%
# a. Print the first element of name_list
print(name_list[0])
# Out:
# Rajesh

# %%
# b. Print the last element of name_list
print(name_list[4])
# Out:
# Swathi

# %%
# c. Print the elements from index 2 to index 4 in name_list
print(name_list[2:4])
# Out:
# ['Gowtham', 'Reena']

# %%
# d. Print the elements of name_list in reverse order
print(name_list[::-1])
# Out:
# ['Swathi', 'Reena', 'Gowtham', 'Rajive', 'Rajesh']

# %% [markdown]
# #Dictionary (Creation, Modification and Access):

# %%
# a. Create a dictionary named student_marks that maps the names of five students to their marks (use scale of from 0 to 100).
student_marks = {
    'Rajesh': 65,
    'Rajive': 92,
    'Gowtham': 78,
    'Reena': 55,
    'Swathi': 100
}

print(student_marks)
# Out:
# {'Rajesh': 65, 'Rajive': 92, 'Gowtham': 78, 'Reena': 55, 'Swathi': 100}

# %%
# b. Access and print the mark of a specific student, of your choice.
print("Gowttham's Mark:",student_marks['Gowtham'])
# Out:
# Gowttham's Mark: 78

# %%
# c. Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
student_marks['Yazhini'] = 72
print(student_marks)
# Out:
# {'Rajesh': 65, 'Rajive': 92, 'Gowtham': 78, 'Reena': 55, 'Swathi': 100, 'Yazhini': 72}

# %%
# d. Update the mark of any one older student to 82.
student_marks['Rajive'] = 95
print(student_marks)
# Out:
# {'Rajesh': 65, 'Rajive': 95, 'Gowtham': 78, 'Reena': 55, 'Swathi': 100, 'Yazhini': 72}

# %%
# e. Use the keys(), values(), and items() methods to print all keys, values, and key-value pairs in the student_marks dictionary.

# Print all keys (student names)
print("Keys:", student_marks.keys())

# Print all values (marks)
print("Values:", student_marks.values())

# Print all key-value pairs
print("Items:", student_marks.items())
# Out:
# Keys: dict_keys(['Rajesh', 'Rajive', 'Gowtham', 'Reena', 'Swathi', 'Yazhini'])
# Values: dict_values([65, 95, 78, 55, 100, 72])
# Items: dict_items([('Rajesh', 65), ('Rajive', 95), ('Gowtham', 78), ('Reena', 55), ('Swathi', 100), ('Yazhini', 72)])

# %% [markdown]
# #Sets (Operations):

# %%
# a. Create a set called my_set with following values: ['a','e','i','o','u','a','a','i'] Analyse the output and provide explanation for the same.

my_set = {'a','e','i','o','u','a','a','i'} #
print(my_set)
# Out:
# {'a', 'o', 'i', 'e', 'u'}

# %% [markdown]
# The output is {'a', 'o', 'i', 'e', 'u'} becoz Sets do not allow duplicate.elements.

# %%
# b. Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.

#my_set[4] = 's'
print(my_set)

#Sets are unordered and unindexed in Python, There is no fixed posision so we can't change using index
# Out:
# {'a', 'o', 'i', 'e', 'u'}

# %%
# c. Create two sets: set1 with values: {1, 3, 5, 7, 9} set2 with values: {2, 3, 5, 8, 10}

set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}

# %%
# d. Compute and print the union and intersection of set1 and set2.

#union

union_set = set1 | set2
print("Union_Set :",union_set)

#intersection

intersection = set1 & set2
print("Common in sets :",intersection)
# Out:
# Union_Set : {1, 2, 3, 5, 7, 8, 9, 10}
# Common in sets : {3, 5}

# %% [markdown]
# #Operators & Conditional Statements : (IF, ELIF, ELSE)

# %% [markdown]
# #Performance Category Program:

# %%
score = int(input("Enter your score (0 to 10): ")) # 1. Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
# 2. Find the performance category based on the input score using following criteria:
if 0 <= score <= 10:
    if score > 7:
        print(f"You've got {score} — It's Above Average.") #3. Output: Print the Performance category
        print("Great job! Keep it up.")
    elif 4 <= score <= 7:
        print(f"You've got {score} — it's Average.")
        print("Good effort! Keep practicing, there's room for improvement.")
    else:
        print(f"You've got {score} — It's Below Average.")
        print("Need to improve your performance, consistent practice will lead to better results.") # 4. Additional Step: You can give a prompt of your choice to each category. For eg: If score below average “Need to Improve your performance, consistent practice will lead to better results”.
else:
    print("Invalid score! Please enter a value between 0 and 10.")
# Out:
# Enter your score (0 to 10): 6
# You've got 6 — it's Average.
# Good effort! Keep practicing, there's room for improvement.
